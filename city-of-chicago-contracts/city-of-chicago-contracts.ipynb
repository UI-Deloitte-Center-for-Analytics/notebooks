# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://github.com/UI-Deloitte-Center-for-Analytics/datasets/blob/main/city-of-chicago-contracts-since-1993.csv?raw=true')
# Out:
# C:\Users\Park\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(3)
# Out:
#                  Purchase Order Description Purchase Order (Contract) Number  \
# 0                                DEMOLITION                          E011442
# 1                       JANITORIAL SUPPLIES                           T27500
# 2  MASTER AGREEMENT FOR DEMOLITION SERVICES                           C02163
#
#   Revision Number Specification Number Contract Type  Start Date    End Date  \
# 0               0           E968020030           NaN         NaN         NaN
# 1               0            B74851001           NaN  12/01/1997  11/30/1999
# 2               0            B89683203           NaN         NaN         NaN
#
#   Approval Date               Department                         Vendor Name  \
# 0           NaN  DEPARTMENT OF BUILDINGS         MIDWEST WRECKING COMPANY 01
# 1           NaN                      NaN  CHICAGO UNITED INDUSTRIES, LIMITED
# 2           NaN  DEPARTMENT OF BUILDINGS  DEMOLITION & DEVELOPMENT, LIMITED.
#
# ...
