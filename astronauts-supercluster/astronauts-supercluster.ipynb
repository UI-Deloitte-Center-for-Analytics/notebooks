# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://github.com/UI-Deloitte-Center-for-Analytics/datasets/raw/main/astronauts-supercluster.csv')

df.head(5)
# Out:
#   s.no/code given  Astronaut name                    country  \
# 0             612     Cameron Bess  United States of America
# 1             611        Lane Bess  United States of America
# 2             610        Evan Dick  United States of America
# 3             609     Dylan Taylor  United States of America
# 4             608  Michael Strahan  United States of America
#
#   company space agency missions days in space spacewalks days spacewalking  \
# 0          Blue Origin        1           <.1          -                 -
# 1          Blue Origin        1           <.1          -                 -
# 2          Blue Origin        1           <.1          -                 -
# 3          Blue Origin        1           <.1          -                 -
# 4          Blue Origin        1           <.1          -                 -
#
#          acheivement 1 acheivement 2 acheivement 3 acheivement 4  \
# 0  Crossed Kármán Line           NaN           NaN           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   s.no/code given       942 non-null    object
#  1   Astronaut name        952 non-null    object
#  2   country               952 non-null    object
#  3   company space agency  629 non-null    object
#  4   missions              952 non-null    object
#  5   days in space         621 non-null    object
#  6   spacewalks            621 non-null    object
#  7   days spacewalking     621 non-null    object
#  8   acheivement 1         734 non-null    object
#  9   acheivement 2         403 non-null    object
#  10  acheivement 3         215 non-null    object
#  11  acheivement 4         331 non-null    object
#  12  still in space        10 non-null     object
# dtypes: object(13)
# memory usage: 96.8+ KB

# %%
df['missions'].unique()
# Out:
# array(['1', '2', '3', '4', '5', '6', '7', '-'], dtype=object)

# %%
df.loc[df['missions'] == '-', 'missions'] = 0

# %%
df['missions'].unique()
# Out:
# array(['1', '2', '3', '4', '5', '6', '7', 0], dtype=object)

# %%
df.columns
# Out:
# Index(['s.no/code given', 'Astronaut name ', 'country', 'company space agency',
#        'missions', 'days in space', 'spacewalks', 'days spacewalking',
#        'acheivement 1', 'acheivement 2', 'acheivement 3', 'acheivement 4',
#        'still in space'],
#       dtype='object')

# %%
df['missions'] = df['missions'].astype(np.int64)

# %%
df.sort_values('missions', ascending=False)
# Out:
#     s.no/code given                  Astronaut name   \
# 603             204           Franklin R. Chang Díaz
# 608             199                    Jerry L. Ross
# 904             A38  Kusachka/Otvazhnaya (Brave One)
# 294             318                 Yuri Malenchenko
# 218             394            Frederick W. Sturckow
# ..              ...                              ...
# 946             NaN                  Jessica Watkins
# 945             NaN                     Larry Connor
# 944             NaN                       Mark Pathy
# 942             NaN                 Roger B. Chaffee
# 951             NaN                    Deng Qingming
#
#                       country company space agency  missions days in space  \
# 603  United States of America                 NASA         7          66.8
# 608  United States of America                 NASA         7            58
# 904                      USSR                  NaN         7           NaN
# ...
